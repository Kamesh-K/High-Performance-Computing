# %%
import seaborn as sns 
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('Temperature_Profile.csv')

# %%
# Out:
#       3.0000e+02  3.0000e+02.1  3.0000e+02.2  3.0000e+02.3  3.0000e+02.4  \
# 0          300.0         300.0         300.0         300.0         300.0
# 1          300.0         300.0         300.0         300.0         300.0
# 2          300.0         300.0         300.0         300.0         300.0
# 3          300.0         300.0         300.0         300.0         300.0
# 4          300.0         300.0         300.0         300.0         300.0
# ...          ...           ...           ...           ...           ...
# 9994       300.0         300.0         300.0         300.0         300.0
# 9995       300.0         300.0         300.0         300.0         300.0
# 9996       300.0         300.0         300.0         300.0         300.0
# 9997       300.0         300.0         300.0         300.0         300.0
# 9998       300.0         300.0         300.0         300.0         300.0
#
#       3.0000e+02.5  3.0000e+02.6  3.0000e+02.7  3.0000e+02.8  3.0000e+02.9  \
# ...
